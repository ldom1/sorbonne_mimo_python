# %% [markdown]
# # Chapitre 1 - Les Bases du Langage - Corrigé exercices

# %% [markdown]
# # Types de Données et Variables
#
# ## 2. Les nombres

# %% [markdown]
# ### Exercice 🐍
#
# L'objectif de cet exercice est de vous familiariser avec les méthodes de manipuation des variables de type `int` et `float` en Python.
#
# ##### Objectifs
# - Comprendre la différence entre les types de données `int` et `float`
# - Savoir manipuler les variables de type `int` et `float`
# - Savoir utiliser les opérateurs de comparaison & les opérateurs arithmétiques
# - Savoir utiliser la fonction `print` pour afficher des messages à l'écran
#
# ##### Instructions
# 1. Créez deux variables `a` et `b` avec des valeurs numériques de votre choix: a: entier, b: réel.
# 2. Affichez leur somme, leur différence, leur produit, et leur quotient.
# 3. Comparez les deux variables en utilisant l'un des opérateurs de comparaison (`==`, `!=`, `<`, `>`, `<=`, `>=`) et affichez le résultat.
# 4. Modifiez les valeurs de `a` et `b` pour tester différents cas.
# 5. Ajoutez un petit message humoristique dans vos affichages, par exemple : "Est-ce que `a` est plus grand que `b` ? Réponse : ..."

# %%
# 1.
a = 10
b = 20.5

print(a + b)  # 30.5
print(a - b)  # -10.5
print(a * b)  # 205.0
print(a / b)  # 0.4878048780487805
# Out:
# 30.5
# -10.5
# 205.0
# 0.4878048780487805

# %%
a < b
# Out:
# True

# %%
a = 14
b = 17.8

print("Est-ce que a est plus petit que b ?", a < b)  # True
# Out:
# Est-ce que a est plus petit que b ? True

# %% [markdown]
# ## Chaînes de caractères — Corrigé
#
# ### Exercice 🐍 — Chaînes de caractères
#
# 1. f-string avec prenom et nom.
# 2. Slicing sur `phrase`.
# 3. Concaténation et `len`.

# %%
prenom, nom = "Alice", "Dupont"
print(f"Bonjour, {prenom} {nom}.")

phrase = "Python est génial"
print(phrase[:6], phrase[-6:])

complet = prenom + " " + nom
print(len(complet))

# %% [markdown]
# ## Listes — Corrigé
#
# ### Exercice 🐍 — Listes
# 1. Liste `fruits`. 2. Premier et dernier. 3. Slicing. 4. append et `in`.

# %%
fruits = ["pomme", "banane", "orange", "kiwi"]
print(fruits[0], fruits[-1])
print(fruits[1:4])
fruits.append("mangue")
print("pomme" in fruits)

# %% [markdown]
# ## Dictionnaires — Corrigé
#
# ### Exercice 🐍 — Dictionnaires
# 1. Dictionnaire `etudiant`. 2. Nom et moyenne. 3. Clé `ville` et affichage.

# %%
etudiant = {"nom": "Martin", "age": 20, "notes": [12, 14, 11]}
print(etudiant["nom"], sum(etudiant["notes"]) / len(etudiant["notes"]))
etudiant["ville"] = "Lyon"
print(etudiant)

# %% [markdown]
# ## Booléens — Corrigé
#
# ### Exercice 🐍 — Booléens
# 1. `a`, `b` booléens. 2. and, or, not. 3. `n` entre 10 et 20.

# %%
a, b = True, False
print(a and b, a or b, not a)
n = 15
print(10 <= n <= 20)
